# %%
import pandas as pd

# %% [markdown]
# # Materials
#
# The most challenging thing to proceed with this project is the access to valuable data, meaning that all materials and used are dated by year, having a problem on the final amount of data is not going to be enough for having a predictio of the finite resource in the future, the following materials are possible:
# + deforestation
# + water
# + metals
# + minerals
# + fuel
# + coal

# %% [markdown]
# **Global material flows database:**

# %%
G_material_flows = pd.read_csv('data/Global_Material_Flows_Database.csv')
print('Data: ', G_material_flows.shape)
print('Types of materials: ', G_material_flows.Category.unique())
print('Flows: ', G_material_flows['Flow name'].unique())
print('Columns: ', G_material_flows.columns)
print('Units: ', G_material_flows['Flow unit'].unique())
G_material_flows.head()
# Out:
# Data:  (17094, 55)
# Types of materials:  ['Biomass' 'Excavated earthen materials (including soil) nec'
#  'Fossil fuels' 'Metal ores' 'Mixed and complex products nec.'
#  'Non-metallic minerals' 'Products from biomass'
#  'Products from fossil fuels' 'Products from metals'
#  'Products from non-metallic minerals'
#  'Waste for final treatment and disposal']
# Flows:  ['Domestic Extraction' 'Domestic Material Consumption'
#  'Domestic Material Input' 'Exports' 'Imports' 'Physical Trade Balance'
#  'Raw Material Consumption' 'Raw Material Equivalents of exports'
#  'Raw Material Equivalents of imports']
# Columns:  Index(['Country', 'Category', 'Flow name', 'Flow code', 'Flow unit', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
# ...

# %% [markdown]
# ## 1. Deforestation

# %%
Forests = pd.read_csv('data/Deforestation/Bosque_intacto_global.csv')
Forests.head()
# Out:
#    iso  umd_tree_cover_extent_2010__ha      area__ha
# 0  ABW                    2.375066e+01  1.819751e+04
# 1  AFG                    7.179679e+04  6.438572e+07
# 2  AGO                    5.384720e+07  1.247423e+08
# 3  AIA                    1.390852e+03  8.332248e+03
# 4  ALA                    1.030740e+05  1.506432e+05

# %%
loss_forest = pd.read_csv('data/Deforestation/treecover_loss__ha.csv')
print(loss_forest.umd_tree_cover_loss__year.unique())
loss_forest.head()
# Out:
# [2001 2002 2003 2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014
#  2015 2016 2017 2018 2019 2020]
#    iso  umd_tree_cover_loss__year  umd_tree_cover_loss__ha  \
# 0  AFG                       2001                88.092712
# 1  AGO                       2001            101220.621524
# 2  AIA                       2001                 3.878461
# 3  ALA                       2001               396.934826
# 4  ALB                       2001              3729.021031
#
#    gfw_gross_emissions_co2e_all_gases__Mg
# 0                            2.226891e+04
# 1                            3.687662e+07
# 2                            6.267003e+02
# 3                            7.589787e+04
# 4                            1.333223e+06

# %%
Extent_forest = pd.read_csv('data/Deforestation/treecover_extent_2000_in_primary_forests_2001_tropics_only__ha.csv')
Extent_forest.head()
# Out:
#    iso  umd_tree_cover_extent_2000__ha      area__ha
# 0  ABW                    7.516318e+00  1.856510e+01
# 1  AGO                    2.457478e+06  2.458838e+06
# 2  AIA                    0.000000e+00  5.842617e-01
# 3  ARG                    4.412127e+06  4.417360e+06
# 4  ATG                    5.884759e+01  9.061951e+01

# %% [markdown]
# ## 2. Minerals for technologies

# %% [markdown]
# ### 2.1 COPPER

# %% [markdown]
# While there is no shortage of the commodity itself, the quality of available deposits is declining as producers are subject to stricter environmental and social standards. Provoked by these factors, copper prices hit their highest level in a decade in April this year, rising by about 21%.

# %% [markdown]
# USA Stats has a list of commodities with the

# %%
Copper = pd.read_csv('data/Minerals/mcs2022-coppe_salient.csv')
print(Copper.shape)
print(Copper.Year.unique())
Copper.head()
# Out:
# (5, 19)
# [2017 2018 2019 2020 2021]
#   DataSource Commodity  Year  USprod_Mine_kt  USprod_Refinery-primary_kt  \
# 0    MCS2022    Copper  2017            1260                        1040
# 1    MCS2022    Copper  2018            1220                        1070
# 2    MCS2022    Copper  2019            1260                         985
# 3    MCS2022    Copper  2020            1200                         874
# 4    MCS2022    Copper  2021            1200                         950
#
#    USprod_Refinery-secondary_kt  Recycled_Post-consumer_kt  Imports_Ores_kt  \
# 0                            40                        146               14
# 1                            41                        149               32
# 2                            44                        150               27
# 3                            43                        150                2
# 4                            50                        160               13
#
# ...

# %%
Copper2 = pd.read_csv('data/Minerals/mcs2022-coppe_world.csv')
print(Copper2.shape)
Copper2.head()
# Out:
# (36, 5)
#     Source        Country                               Type  Prod_kt_2020  \
# 0  MCS2022  United States  Mine production, contained copper          1200
# 1  MCS2022      Australia  Mine production, contained copper           885
# 2  MCS2022         Canada  Mine production, contained copper           585
# 3  MCS2022          Chile  Mine production, contained copper          5730
# 4  MCS2022          China  Mine production, contained copper          1720
#
#    Prod_kt_Est_2021
# 0              1200
# 1               900
# 2               590
# 3              5600
# 4              1800

# %% [markdown]
# ### 2.2 Lithium

# %% [markdown]
# Lithium, the lightest of all metals, is used in air treatment, batteries, ceramics, glass, metallurgy, pharmaceuticals, and polymers

# %%
litio = pd.read_csv('data/Minerals/Lith_stat_Geo.csv')
print(litio.shape)

litio
# Out:
# (118, 8)
#      Year Production  Imports  Exports  Estimated consumption  \
# 0    1900       10.4      NaN      NaN                   10.4
# 1    1901       35.0      NaN      NaN                   35.0
# 2    1902       24.9      NaN      NaN                   24.9
# 3    1903       23.1      NaN      NaN                   23.1
# 4    1904       11.5      NaN      NaN                   11.5
# ..    ...        ...      ...      ...                    ...
# 113  2013        870     2.21     1.23                    1.8
# 114  2014          W     2.13     1.42                    2.0
# 115  2015          W     2.75     1.79                    2.0
# 116  2016          W     3.14     1.52                    3.0
# 117  2017          W     3.33     1.96                    3.0
#
#      Unit value ($/t)  Unit value (98$/t) World production (gross weight)
# 0                 NaN                 NaN                             NaN
# ...

# %%
litio2 = pd.read_csv('data/Minerals/mcs2022-lithi_world.csv')
print(litio2.shape)

litio2
# Out:
# (9, 5)
#     Source                Country                                Type  \
# 0  MCS2022          United States  Mine production, contained lithium
# 1  MCS2022              Argentina  Mine production, contained lithium
# 2  MCS2022              Australia  Mine production, contained lithium
# 3  MCS2022                 Brazil  Mine production, contained lithium
# 4  MCS2022                  Chile  Mine production, contained lithium
# 5  MCS2022                  China  Mine production, contained lithium
# 6  MCS2022               Portugal  Mine production, contained lithium
# 7  MCS2022               Zimbabwe  Mine production, contained lithium
# 8  MCS2022  World total (rounded)  Mine production, contained lithium
#
#   Prod_t_2020 Prod_t_Est_2021
# 0           W               W
# 1        5900            6200
# 2       39700           55000
# 3        1420            1500
# 4       21500           26000
# 5       13300           14000
# 6         348             900
# ...

# %% [markdown]
# ### 2.3 Magnesium

# %%
magnes = pd.read_csv('data/Minerals/mcs2022-mgmet_world.csv')
print(magnes.shape)

magnes
# Out:
# (9, 5)
#     Source                Country                Type Prod_kt_2020  \
# 0  MCS2022          United States  Smelter production            W
# 1  MCS2022                 Brazil  Smelter production           18
# 2  MCS2022                  China  Smelter production          886
# 3  MCS2022                 Israel  Smelter production           19
# 4  MCS2022             Kazakhstan  Smelter production           16
# 5  MCS2022                 Russia  Smelter production           48
# 6  MCS2022                 Turkey  Smelter production           12
# 7  MCS2022                Ukraine  Smelter production            6
# 8  MCS2022  World total (rounded)  Smelter production         1000
#
#   Prod_kt_Est_2021
# 0                W
# 1               20
# 2              800
# 3               22
# 4               20
# 5               60
# 6               15
# 7               10
# 8              950

# %% [markdown]
# ## 2. OIL

# %%
Statistical = pd.read_csv('data/Oil/bp-stats-review-2021-consolidated-dataset-narrow-format.csv')
print(Statistical.shape)
print(Statistical['Year'].unique())
Statistical.sample(6)
# Out:
# (252916, 12)
# [1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978
#  1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992
#  1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#  2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020]
#                          Country  Year ISO3166_alpha3  ISO3166_numeric  \
# 156597                   Germany  2002            DEU            276.0
# 31244                     France  1994            FRA            250.0
# 87021   Total S. & Cent. America  1975            NaN              NaN
# 216815                    Israel  2006            ISR            376.0
# 177041                  Slovenia  2007            SVN            705.0
# 34217             Total Non-OECD  2017            NaN              NaN
#
#              Region    SubRegion  OPEC   EU  OECD  CIS              Var  \
# 156597       Europe       Europe   0.0  1.0   1.0  0.0     gasprod_bcfd
# ...

# %% [markdown]
# ## 2. Water

# %%
water_resource = pd.read_csv('data/Water/Water_resource_long-term.csv')
water_resource.head()
# Out:
#               DATAFLOW        LAST UPDATE freq    unit geo  wat_proc  \
# 0  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT  EVAP_TSP
# 1  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT  INFL_NBT
# 2  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT     INTFL
# 3  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT     OUTFL
# 4  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT    PRECIP
#
#    TIME_PERIOD  OBS_VALUE  OBS_FLAG LTAA_FLAG      LTAA
# 0          NaN        NaN       NaN       NaN   4853.65
# 1          NaN        NaN       NaN       NaN   3299.58
# 2          NaN        NaN       NaN       NaN   6385.19
# 3          NaN        NaN       NaN       NaN   9684.77
# 4          NaN        NaN       NaN       NaN  11238.84

# %%
# Per m3 of habitants
water_abstraction = pd.read_csv('data/Water/Freshwater_abstraction_bysource_and_sector.csv')
water_abstraction.head()
# Out:
#                  DATAFLOW        LAST UPDATE freq wat_proc wat_src    unit  \
# 0  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 1  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 2  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 3  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 4  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
#
#   geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0  AL         2017      37.68        e
# 1  AL         2018      34.62      NaN
# 2  AL         2019      30.32      NaN
# 3  BE         1994      66.23      NaN
# 4  BE         1995      70.61      NaN
