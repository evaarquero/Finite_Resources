# %%
import pandas as pd

# %% [markdown]
# Medium blogs on resources analysis:
# - https://medium.com/towards-data-science/why-green-silver-just-might-be-the-new-black-gold-1694ac5562bf
# - https://towardsdatascience.com/an-approach-to-make-comparison-of-arima-and-nnar-models-for-forecasting-price-of-commodities-f80491aeb400
# - https://towardsdatascience.com/forecasting-the-copper-producer-price-index-with-prophet-d570e3baac78

# %% [markdown]
# ## Finite resources

# %%
df = pd.read_csv('ideas_proyectos/WPA15 - Wholesale Price Index (Excl VAT) for Building and Construction Materials.csv')

# %%
df
# Out:
#     STATISTIC                                          Statistic  TLIST(A1)  \
# 0    WPA15C01  Wholesale Price Index (Excl VAT) for Building ...       2015
# 1    WPA15C01  Wholesale Price Index (Excl VAT) for Building ...       2015
# 2    WPA15C01  Wholesale Price Index (Excl VAT) for Building ...       2015
# 3    WPA15C01  Wholesale Price Index (Excl VAT) for Building ...       2015
# 4    WPA15C01  Wholesale Price Index (Excl VAT) for Building ...       2015
# ..        ...                                                ...        ...
# 555  WPA15C02  Percentage Change over 12 month in Capital Goo...       2021
# 556  WPA15C02  Percentage Change over 12 month in Capital Goo...       2021
# 557  WPA15C02  Percentage Change over 12 month in Capital Goo...       2021
# 558  WPA15C02  Percentage Change over 12 month in Capital Goo...       2021
# 559  WPA15C02  Percentage Change over 12 month in Capital Goo...       2021
#
# ...

# %%
df2 = pd.read_csv('ideas_proyectos/DP_LIVE_01032022132636940.csv')

# %%
df2
# Out:
#      LOCATION   INDICATOR SUBJECT    MEASURE FREQUENCY  TIME    Value  \
# 0         AUS  MATCONSUMP     TOT  TONNE_CAP         A  1970  26.7161
# 1         AUS  MATCONSUMP     TOT  TONNE_CAP         A  1971  26.5389
# 2         AUS  MATCONSUMP     TOT  TONNE_CAP         A  1972  27.8444
# 3         AUS  MATCONSUMP     TOT  TONNE_CAP         A  1973  28.9403
# 4         AUS  MATCONSUMP     TOT  TONNE_CAP         A  1974  29.3210
# ...       ...         ...     ...        ...       ...   ...      ...
# 6531     EU27  MATCONSUMP     TOT  TONNE_CAP         A  2015  13.8139
# 6532     EU27  MATCONSUMP     TOT  TONNE_CAP         A  2016  13.7910
# 6533     EU27  MATCONSUMP     TOT  TONNE_CAP         A  2017  14.1958
# 6534     EU27  MATCONSUMP     TOT  TONNE_CAP         A  2018  14.3987
# 6535     EU27  MATCONSUMP     TOT  TONNE_CAP         A  2019  14.2387
#
#      Flag Codes
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# ...

# %%
DS1 = pd.read_csv('ideas_proyectos/DS1.csv')

# %%
DS2 = pd.read_csv('ideas_proyectos/DS2.csv')

# %%
growth = pd.read_csv('data/Growth_data.csv')
growth.head()
# Out:
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  Population growth (annual %)
# 1  Africa Eastern and Southern          AFE  Population growth (annual %)
# 2                  Afghanistan          AFG  Population growth (annual %)
# 3   Africa Western and Central          AFW  Population growth (annual %)
# 4                       Angola          AGO  Population growth (annual %)
#
#   Indicator Code      1960      1961      1962      1963      1964      1965  \
# 0    SP.POP.GROW       NaN  2.236462  1.432843  0.823502  0.580334  0.573498
# 1    SP.POP.GROW       NaN  2.539822  2.575182  2.606839  2.633213  2.656488
# 2    SP.POP.GROW       NaN  1.898499  1.965805  2.029830  2.090208  2.147639
# 3    SP.POP.GROW  2.034308  2.085972  2.133725  2.173361  2.202845  2.226134
# 4    SP.POP.GROW       NaN  1.392891  1.383296  1.256405  0.973970  0.618450
#
# ...

# %%
fuel = pd.read_csv('data/Fuel_exports.csv')
fuel.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                             Indicator Name     Indicator Code  1960  1961  \
# 0  Fuel exports (% of merchandise exports)  TX.VAL.FUEL.ZS.UN   NaN   NaN
# 1  Fuel exports (% of merchandise exports)  TX.VAL.FUEL.ZS.UN   NaN   NaN
# 2  Fuel exports (% of merchandise exports)  TX.VAL.FUEL.ZS.UN   NaN   NaN
# 3  Fuel exports (% of merchandise exports)  TX.VAL.FUEL.ZS.UN   NaN   NaN
# 4  Fuel exports (% of merchandise exports)  TX.VAL.FUEL.ZS.UN   NaN   NaN
#
#        1962      1963      1964       1965  ...       2012       2013  \
# 0       NaN       NaN       NaN        NaN  ...   0.046983   0.003385
# 1       NaN       NaN       NaN        NaN  ...  27.550125  26.282629
# ...

# %%
resource_product_EU = pd.read_csv('data/Resource_productivity.csv')  # OBS_Value =m3_habitant
# EUR_KG_CLV15 : Euro per kilogram, chain linked volumes (2015)
# I00 : Index 2000
# PPS_KG : Purchasing power standard (PPS) per kilogram
# THS_T : Thousand tones
resource_product_EU.head()
# Out:
#                DATAFLOW        LAST UPDATE freq          unit geo  \
# 0  ESTAT:SDG_12_20(1.0)  30/06/21 23:00:00    A  EUR_KG_CLV15  AT
# 1  ESTAT:SDG_12_20(1.0)  30/06/21 23:00:00    A  EUR_KG_CLV15  AT
# 2  ESTAT:SDG_12_20(1.0)  30/06/21 23:00:00    A  EUR_KG_CLV15  AT
# 3  ESTAT:SDG_12_20(1.0)  30/06/21 23:00:00    A  EUR_KG_CLV15  AT
# 4  ESTAT:SDG_12_20(1.0)  30/06/21 23:00:00    A  EUR_KG_CLV15  AT
#
#    TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0         2000     1.7344        b
# 1         2001     1.8024      NaN
# 2         2002     1.7007      NaN
# 3         2003     1.8154      NaN
# 4         2004     1.7776      NaN

# %%
fresh_water_EU = pd.read_csv('data/Freshwater_abstraction_bysource_and_sector.csv')  
# OBS_Value = m3_habitant and mio_M3 (million cubic meters)
fresh_water_EU.head()
# Out:
#                  DATAFLOW        LAST UPDATE freq wat_proc wat_src    unit  \
# 0  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 1  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 2  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 3  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
# 4  ESTAT:ENV_WAT_ABS(1.0)  12/01/22 23:00:00    A     ABST     FGW  M3_HAB
#
#   geo  TIME_PERIOD  OBS_VALUE OBS_FLAG
# 0  AL         2017      37.68        e
# 1  AL         2018      34.62      NaN
# 2  AL         2019      30.32      NaN
# 3  BE         1994      66.23      NaN
# 4  BE         1995      70.61      NaN

# %%
water_resource = pd.read_csv('data/Water_resource_long-term.csv')

water_resource.head()
# Out:
#               DATAFLOW        LAST UPDATE freq    unit geo  wat_proc  \
# 0  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT  EVAP_TSP
# 1  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT  INFL_NBT
# 2  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT     INTFL
# 3  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT     OUTFL
# 4  ESTAT:TEN00001(1.0)  12/01/22 23:00:00    A  M3_HAB  AT    PRECIP
#
#    TIME_PERIOD  OBS_VALUE  OBS_FLAG LTAA_FLAG      LTAA
# 0          NaN        NaN       NaN       NaN   4853.65
# 1          NaN        NaN       NaN       NaN   3299.58
# 2          NaN        NaN       NaN       NaN   6385.19
# 3          NaN        NaN       NaN       NaN   9684.77
# 4          NaN        NaN       NaN       NaN  11238.84

# %%
material_import_dep = pd.read_csv('data/Material_import_dependency.csv')
material_import_dep.head()

# %% [markdown]
# Se habla mucho de Material flows y su productividad
#
# Tambien resources and material rent

# %%
material_flows = pd.read_csv('data/Global_Material_Flows_Database.csv') ## https://www.resourcepanel.org/data-resources
print(material_flows.shape)
print(material_flows.Category.unique())
material_flows.sample(4) 
# Para visualizar, se puede hacer algo asi
# Out:
# (17094, 55)
# ['Biomass' 'Excavated earthen materials (including soil) nec'
#  'Fossil fuels' 'Metal ores' 'Mixed and complex products nec.'
#  'Non-metallic minerals' 'Products from biomass'
#  'Products from fossil fuels' 'Products from metals'
#  'Products from non-metallic minerals'
#  'Waste for final treatment and disposal']
#           Country                                          Category  \
# 16384  Uzbekistan                             Non-metallic minerals
# 2737       Canada  Excavated earthen materials (including soil) nec
# 6252       Guinea                              Products from metals
# 2750       Canada                                        Metal ores
#
#                                  Flow name Flow code Flow unit         1970  \
# 16384  Raw Material Equivalents of exports   RME_EXP         t          0.0
# 2737                               Imports       IMP         t          0.0
# ...

# %% [markdown]
# # Resources on industries
# ## 1. Tipos de industria:
# Los tipos de industria son las categorías en las que podemos clasificar aquellas empresas que transforman las materias primas en productos de consumo final o intermedio. [Tipos de industria](https://economipedia.com/definiciones/tipos-de-industria.html)
#
# Podemos clasificar además las industrias de acuerdo al sector económico al que pertenecen, como en el siguientes ejemplos:
# 1. Alimentaria.
# 2. Textil.
# 3. Química / Farmaceútica.
# 4. Siderúrgica (dedicada a la producción de hierro y acero). / Cementera ---- CONSTRUCCION*
# 5. Militar.
# 6. Automovilística
# 7. Electronica / Tecnologías
#
#
# Siderúrgica y cementera, podríamos unificarla en ==construccion==.
# Evaluar si turistica y forestal, qué tipos de recursos se llevan estas industrias? o qué entraría en estas dos industrias.

# %% [markdown]
# ## 1.1 Alimentación

# %% [markdown]
# *Agriculture now occupies roughly half of the plant-habitable surface of the planet, uses 69% of extracted fresh water and, together with the rest of the food system, is responsible for 25 – 30% of greenhouse gas emissions. The expansion of industrial fishing fleets and a higher demand for seafood globally have led to the collapse or total exploitation of over 90% of the world’s marine fisheries. A growing demand for land-based animal products is the primary driver of tropical deforestation. Through its direct and intermediate impacts, the food system is the largest contributor to the depletion of biodiversity.
#
# *Increased population and growing wealth suggest that a doubling of food production may be necessary by 2050*
#
# *The planetary boundaries and unsustainable resource extraction are hard limits to the food system’s further expansion based on past trends*
# [global-food-system](https://www.metabolic.nl/publication/global-food-system-an-analysis/)
#
# ![Alimentacion](data/Alimentacion/GlobalFoodSystem8.png)
#
# Beef, soy and palm oil are responsible for 60% of [tropical deforestation](https://ourworldindata.org/drivers-of-deforestation) - [Global forest](https://www.globalforestwatch.org/dashboards/global/?category=land-cover&dashboardPrompts=%3D%3D&location=WyJnbG9iYWwiXQ%3D%3D&map=...%3D%3D&showMap=true)
#
# Resources (http://scp-hat.lifecycleinitiative.org/methods/)
#
# What about transport and packaging?

# %% [markdown]
# ## 1.2 Textil

# %% [markdown]
# *The impact of the textile sector involves the environment and climate. Some data published by the European Environment Agency in 2017 estimate that the textile industry consumes 1.3 tons of raw materials and 104 cubic meters of water per person, each year.
#
# Appart from the use of water, energy and product a lot of waste, the textile industry will not have any bigger problem in the future.

# %% [markdown]
# ## 1.3 Química y farmaceutica

# %% [markdown]
# Demand for natural ingredients from the cosmetics sector in Europe is growing.
# - Vegetable or animal derived oils, fats and waxes:  palm oil, coconut oil, sunflower oil, rapeseed oil, hemp oil and avocado oil  (Deforestation, how much deforestation is due to chemical industry)

# %% [markdown]
# ## 1.4 Construccion

# %% [markdown]
# THe construction called industry is divided in:
#   + Cement industry
#   + Metalurgycal industry
#
# ### 1.4.1 Cememt industry:
# The most important raw materials for making cement are limestone, clay, and marl

# %% [markdown]
# ## 1.5 Militar

# %% [markdown]
# ## 1.6 Automovilistica

# %% [markdown]
# ## 1.7 Tecnologia

# %%
Silicon
Silver: In microchips, photovoltaic,

# %% [markdown]
# ## 2. Human development

# %%
# From UN-- life expentancy
human = pd.read_csv('data/WPP2019_Period_Indicators_Medium.csv') ## https://www.resourcepanel.org/data-resources
print(human.shape)
print(human['Location'].unique())
print(human.columns)
human.sample(4)
# Out:
# (14940, 25)
# ['Afghanistan' 'Africa' 'African Group' 'African Union'
#  'African Union: Central Africa' 'African Union: Eastern Africa'
#  'African Union: Northern Africa' 'African Union: Southern Africa'
#  'African Union: Western Africa'
#  'African, Caribbean and Pacific (ACP) Group of States' 'Albania'
#  'Algeria' 'American Samoa' 'Andean Community' 'Andorra' 'Angola'
#  'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Asia'
#  'Asia-Pacific Economic Cooperation (APEC)' 'Asia-Pacific Group'
#  'Association of Southeast Asian Nations (ASEAN)' 'Australia'
#  'Australia/New Zealand' 'Austria' 'Azerbaijan' 'BRIC' 'BRICS' 'Bahamas'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize'
#  'Belt-Road Initiative (BRI)' 'Belt-Road Initiative: Africa'
#  'Belt-Road Initiative: Asia' 'Belt-Road Initiative: Europe'
#  'Belt-Road Initiative: Latin America and the Caribbean'
#  'Belt-Road Initiative: Pacific' 'Benin' 'Bermuda' 'Bhutan'
# ...

# %% [markdown]
# Markdown examples
#
# [title](https://www.example.com)
#
# [alt text](image.jpg)
#
# # H1
# ## H2
# ### H3
# **bold text**
#
# *italicized text*
# > blockquote
# 1. First item
# 2. Second item
# 3. Third item
# Unordered List
# - First item
# - Second item
# - Third item
# `code`
# ---
# Table:
#
# | Syntax | Description |
# | ----------- | ----------- |
# | Header | Title |
# | Paragraph | Text |
#
# ```
# {
#   "firstName": "John",
#   "lastName": "Smith",
#   "age": 25
# }
# ```
#
# Here's a sentence with a footnote. [^1]
#
# [^1]: This is the footnote.
#
# ### My Great Heading {#heading}
#
# term
# : definition
#
# ~~The world is flat.~~
#
# - [x] Write the press release
# - [ ] Update the website
# - [ ] Contact the media
#
#
# That is so funny! :joy:
# Tambien con windows+'.': 😂
#
# I need to highlight these ==very important words==.
#
# Subscript:	H~2~O
#
# Superscript: 	X^2^
